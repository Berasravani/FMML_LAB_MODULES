# %% [markdown]
# <a href="https://colab.research.google.com/github/Berasravani/FMML_LAB_MODULES/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 08:09:00--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   136MB/s    in 0.5s
#
# 2024-03-31 08:09:00 (136 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 17222  1709.05522v1  An open-source Mandarin speech corpus called A...    cs
# 12463  1802.03840v1  Exploratory data analysis is a crucial task fo...  stat
# 10659   1206.5278v1  Conditional density estimation generalizes reg...  stat
# 5525    1205.5819v2  It was proved in 1998 by Ben-David and Litman ...  stat
# 7557   1802.03488v1  An important issue in neural network research ...  stat
# ...             ...                                                ...   ...
# 14314  1803.04464v1  We consider the problem of variable selection ...  stat
# 13011   1212.0945v1  We present a graph-based variational algorithm...  stat
# 26451  1610.06204v2  We present a Reinforcement Learning (RL) solut...    cs
# 10965   1211.5414v1  This note gives a simple analysis of a randomi...    cs
# 7552   1802.03212v1  Deep neural networks are a family of computati...  stat
#
#                                                    title  year  \
# 17222  AISHELL-1: An Open-Source Mandarin Speech Corp...  2017
# 12463  Uncharted Forest a Technique for Exploratory D...  2018
# 10659  Fast Nonparametric Conditional Density Estimation  2012
# 5525   Measurability Aspects of the Compactness Theor...  2012
# 7557   Generalization of an Upper Bound on the Number...  2018
# ...                                                  ...   ...
# 14314    False Discovery Rate Control via Debiased Lasso  2018
# 13011  Multiclass Diffuse Interface Models for Semi-S...  2012
# 26451  A Reinforcement Learning Approach to the View ...  2016
# 10965  Analysis of a randomized approximation scheme ...  2012
# 7552                Deep clustering of longitudinal data  2018
#
#                                                 keywords
# 17222  [conducting, recognition, recognition, recordi...
# 12463  [exploratory, developing, effective, classific...
# 10659  [conditional, estimation, generalizes, regress...
# 5525   [compression, compression, compactness, measur...
# 7557   [important, classification, intuitions, separa...
# ...                                                  ...
# 14314  [selection, dimensional, statistical, variable...
# 13011  [variational, algorithm, multiclass, classific...
# 26451  [reinforcement, generates, accessible, represe...
# 10965  [randomized, approximation, multiplication, be...
# 7552   [computational, dramatical, improvement, frame...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 17222    [conducting, recognition, recognition, recordi...
# 12463    [exploratory, developing, effective, classific...
# 10659    [conditional, estimation, generalizes, regress...
# 5525     [compression, compression, compactness, measur...
# 7557     [important, classification, intuitions, separa...
#                                ...
# 36218    [development, development, production, computa...
# 38387    [minimization, syntactic, dependencies, establ...
# 27613    [convolutional, promising, prediction, predict...
# 12160    [transformed, artificial, intelligence, includ...
# 4457     [unsupervised, generation, increasing, attenti...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8876 words.
# Out of those 4635 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f2beaec2-f11e-435d-9c9c-998379600da0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2beaec2-f11e-435d-9c9c-998379600da0")) {                    Plotly.newPlot(                        "f2beaec2-f11e-435d-9c9c-998379600da0",                        [{"x":["environments","resources","recordings","capturing","presented","recognition","recording","procedure","transcriptions","experimental","described","preparation","including","promising","conducting","quantified","validated","mechanisms","exemplary","dimensional","clustering","partitioned","exploratory","associations","association","comparing","elucidating","provenance","membership","effective","technique","uninformative","probabilistic","constructed","algorithms","unsupervised","classification","partitions","variables","developing","heterogeneity","advantages","probabilities","limitations","statisticians","difficulty","attention","bandwidth","generating","applications","conditional","prediction","fundamental","presumably","applicable","criterion","techniques","bivariate","relatively","experiments","estimation","intractable","intervals","generalizes","previously","estimator","likelihood","nonparametric","computational","selection","estimators","important","multivariate","community","regression","necessary","guaranteed","hypotheses","condition","subspaces","introduce","separable","learnability","measurable","universally","compactness","compression","additionally","increasing","functions","aforementioned","asymptote","algorithm","structure","separately","activation","generalization","sufficient","empirically","rectified","conditions","separability","intuitions","concretely","minimizing","optimization","stochastic","constraints","feasibility","convergence","structural","violation","literature","alternating","necessarily","multipliers","augmented","assumptions","nonsmooth","establish","objective","direction","demonstrate","semantically","leverages","controllable","continuous","generative","correspond","supervised","categorical","adversarial","supervision","categories","maximizing","furthermore","disentangle","synthesis","contribute","representations","synthetic","reasoning","increases","information","architecture","theoretic","introducing","available","maintains","meaningful","consuming","traditional","recognize","different","physicians","examination","investigate","automatic","subjective","detection","involving","annotated","evaluating","comprehensively","consisting","intensive","microscopic","corresponding","particles","similarity","precision","euclidean","producing","overlapped","closeness","observations","overlapping","divergence","correctness","components","asymptotic","numerical","nonconvex","hypothesis","statistical","stationary","efficient","nonlinear","specifically","nonconvexity","parameter","confidence","uncertainty","construct","converges","classical","regularized","inference","nonlinearity","implementation"],"y":[84,73,3,40,185,380,5,116,6,388,70,11,230,122,7,12,32,52,1,194,155,4,4,10,22,81,1,2,21,244,252,3,177,75,611,146,517,16,118,54,5,79,51,61,0,49,174,6,114,413,95,222,95,2,52,40,369,1,62,611,223,25,7,28,96,26,72,20,328,151,11,318,17,62,107,63,30,30,55,18,332,14,3,0,5,8,41,57,110,196,12,1,780,360,37,34,96,71,60,9,131,6,5,3,64,310,130,143,28,109,76,3,125,23,19,18,35,74,4,58,159,56,593,32,30,7,88,119,36,192,15,120,52,69,41,151,8,52,29,239,145,133,53,681,252,39,59,274,12,46,30,190,41,798,9,9,126,187,33,339,56,85,66,6,53,36,6,152,6,154,90,35,34,2,4,89,18,27,10,111,13,69,11,44,143,23,399,47,173,2,110,35,91,74,23,110,43,195,3,144],"type":"bar"},{"x":["environments","resources","recordings","capturing","presented","recognition","recording","procedure","transcription ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4635,), (4635, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8175

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Reconstruction</span> <span style=''>of3</span> <span style=''>D</span> <span style=''>Rigid</span> <span style=''>Smooth</span> <span style=''>Curves</span> <span style=''>Moving</span> <span style=''>Free</span> <span style=''>when</span> <span style=''>Two</span> <span style=''>Traceable</span> <span style=''>Points</span> <span style=''>Only</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Available</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>extends</span> <span style=''>previous</span> <span style=''>research</span> <span style=''>in</span> <span style=''>that</span> <span style=''>sense</span> <span style=''>that</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>orthogonal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>projections</span> <span style=''>of</span> <span style=''>rigid</span> <span style=''>smooth</span> <span style=''>(true</span> <span style=''>3D)</span> <span style=''>curves</span> <span style=''>moving</span> <span style=''>totally</span> <span style=''>free</span> <span style=''>it</span> <span style=''>reduces</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>required</span> <span style=''>traceable</span> <span style=''>points</span> <span style=''>to</span> <span style=''>two</span> <span style=''>only</span> <span style=''>(the</span> <span style=''>best</span> <span style=''>results</span> <span style=''>known</span> <span style=''>so</span> <span style=''>far</span> <span style=''>to</span> <span style=''>the</span> <span style=''>author</span> <span style=''>are</span> <span style=''>3</span> <span style=''>points</span> <span style=''>from</span> <span style=''>free</span> <span style=''>motion</span> <span style=''>and</span> <span style=''>2</span> <span style=''>for</span> <span style=''>motion</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>restricted</span> <span style=''>to</span> <span style=''>rotation</span> <span style=''>around</span> <span style=''>a</span> <span style=''>fixed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>direction</span> <span style=''>and</span> <span style=''>and</span> <span style=''>2</span> <span style=''>for</span> <span style=''>motion</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>restricted</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>influence</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>homogeneous</span> <span style=''>force</span> <span style=''>field)</span> <span style=''>The</span> <span style=''>method</span> <span style=''>used</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploitation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>on</span> <span style=''>tangential</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>projections</span> <span style=''>It</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>discusses</span> <span style=''>also</span> <span style='background-color:rgba(0, 255, 0, 0.5094339622641509);'>possibility</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>simplification</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reconstruction</span> <span style=''>of</span> <span style=''>flat</span> <span style=''>curves</span> <span style=''>moving</span> <span style=''>free</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prospective</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>projections</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Automated</span> <span style=''>Scalable</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>via</span> <span style=''>Hilbert</span> <span style=''>Coresets</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>in</span> <span style=''>Bayesian</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>has</span> <span style=''>enabled</span> <span style=''>experts</span> <span style=''>and</span> <span style=''>nonexperts</span> <span style=''>alike</span> <span style=''>to</span> <span style=''>use</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sophisticated</span> <span style=''>models</span> <span style=''>engage</span> <span style=''>in</span> <span style=''>faster</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploratory</span> <span style=''>modeling</span> <span style=''>and</span> <span style=''>analysis</span> <span style=''>and</span> <span style=''>ensure</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reproducibility</span> <span style=''>However</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tractable</span> <span style=''>at</span> <span style=''>the</span> <span style=''>scale</span> <span style=''>of</span> <span style=''>massive</span> <span style=''>modern</span> <span style=''>datasets</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modifications</span> <span style=''>to</span> <span style=''>make</span> <span style=''>them</span> <span style=''>so</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>model</span> <span style=''>specific</span> <span style=''>require</span> <span style=''>expert</span> <span style=''>tuning</span> <span style=''>and</span> <span style=''>can</span> <span style=''>break</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantees</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inferential</span> <span style=''>quality</span> <span style=''>Building</span> <span style=''>on</span> <span style=''>the</span> <span style=''>Bayesian</span> <span style=''>coresets</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>this</span> <span style=''>work</span> <span style=''>instead</span> <span style=''>takes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>redundancy</span> <span style=''>to</span> <span style=''>shrink</span> <span style=''>the</span> <span style=''>dataset</span> <span style=''>itself</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preprocessing</span> <span style=''>step</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style=''>fully</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automated</span> <span style=''>scalable</span> <span style=''>Bayesian</span> <span style='background-color:r ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>to</span> <span style=''>classify</span> <span style=''>with</span> <span style=''>possible</span> <span style=''>sensor</span> <span style=''>failures</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>a</span> <span style=''>robust</span> <span style=''>large</span> <span style=''>margin</span> <span style=''>binary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>when</span> <span style=''>corrupt</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>anomalies</span> <span style=''>caused</span> <span style=''>by</span> <span style=''>sensor</span> <span style=''>failure</span> <span style=''>might</span> <span style=''>be</span> <span style=''>present</span> <span style=''>in</span> <span style=''>the</span> <span style=''>training</span> <span style=''>set</span> <span style=''>The</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>to</span> <span style=''>minimize</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>error</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>on</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corrupted</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>while</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>controlling</span> <span style=''>the</span> <span style=''>false</span> <span style=''>alarm</span> <span style=''>rate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associated</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>anomalous</span> <span style=''>samples</span> <span style=''>By</span> <span style='background-color:rgba(0, 255, 0, 0.4193548387096774);'>incorporating</span> <span style=''>a</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.41721854304635764);'>parametric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularizer</span> <span style=''>based</span> <span style=''>on</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>entropy</span> <span style='background-color:rgba(255, 0, 0, 0.7045454545454545);'>estimator</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.39130434782608703);'>Geometric</span> <span style=''>Entropy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Minimization</span> <span style='background-color:rgba(255, 0, 0, 0.3533834586466165);'>regularized</span> <span style=''>Maximum</span> <span style=''>Entropy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Discrimination</span> <span style=''>(GEM</span> <span style=''>MED)</span> <span style=''>method</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>to</span> <span style=''>classify</span> <span style=''>and</span> <span style=''>detect</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>anomalies</span> <span style=''>in</span> <span style=''>a</span> <span style=''>joint</span> <span style=''>manner</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.4258373205741627);'>simulated</span> <span style=''>data</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Robust</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Kronecker</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Component</span> <span style=''>Analysis</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Dictionary</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>analysis</span> <span style=''>models</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fundamental</span> <span style=''>in</span> <span style=''>learning</span> <span style=''>compact</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>that</span> <span style=''>are</span> <span style=''>relevant</span> <span style=''>to</span> <span style=''>a</span> <span style=''>given</span> <span style=''>task</span> <span style=''>(feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extraction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>denoising</span> <span style=''>etc)</span> <span style=''>The</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>is</span> <span style=''>encoded</span> <span style=''>by</span> <span style=''>means</span> <span style=''>of</span> <span style=''>specific</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>such</span> <span style=''>as</span> <span style=''>sparsity</span> <span style=''>low</span> <span style=''>rankness</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonnegativity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Unfortunately</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>like</span> <span style=''>K</span> <span style=''>SVD</span> <span style=''>that</span> <span style=''>learn</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionaries</span> <span style=''>for</span> <span style=''>sparse</span> <span style=''>coding</span> <span style=''>via</span> <span style=''>Singular</span> <span style=''>Value</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Decomposition</span> <span style=''>(SVD)</span> <span style=''>are</span> <span style=''>hard</span> <span style=''>to</span> <span style=''>scale</span> <span style=''>to</span> <span style=''>high</span> <span style=''>volume</span> <span style=''>and</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>visual</span> <span style=''>data</span> <span style=''>and</span> <span style=''>fragile</span> <span style=''>in</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>outliers</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Conversely</span> <span style=''>robust</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>analysis</span> <span style=''>methods</span> <span style=''>such</span> <span style=''>as</span> <span style=''>the</span> <span style=''>Robust</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Principle</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Component</span> <span style=''>Analysis</span> <span style=''>(RPCA)</span> <span style=''>are</span> <span style=''>able</span> <span style=''>to</span> <span style=''>recover</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>(eg</span> <span style=''>low</span> <span style=''>rank)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>from</span> <span style=''>data</span> <span  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12589413447782546)
# 	representation (0.13412017167381973)
# 	segmentation (0.07296137339055794)
# 	architecture (0.09012875536480687)
# 	information (0.24356223175965666)
# 	processing (0.11731044349070101)
# 	detection (0.12124463519313304)
# 	different (0.2854077253218884)
# 	recognition (0.13590844062947066)
# 	convolutional (0.15200286123032905)
#
# Some Statistics words are:
# 	theoretical (0.15568862275449102)
# 	stochastic (0.14321357285429143)
# 	estimation (0.17764471057884232)
# 	variables (0.14171656686626746)
# 	statistical (0.15419161676646706)
# 	distribution (0.18912175648702595)
# 	dimensional (0.18712574850299402)
# 	algorithm (0.3972055888223553)
# 	inference (0.1966067864271457)
# 	regression (0.18363273453093812)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3c83f64c-7ed6-4865-9f4b-bb5c444b6c1c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c83f64c-7ed6-4865-9f4b-bb5c444b6c1c")) {                    Plotly.newPlot(                        "3c83f64c-7ed6-4865-9f4b-bb5c444b6c1c",                        [{"x":["environments","resources","recordings","capturing","presented","recognition","recording","procedure","transcriptions","experimental","described","preparation","including","promising","conducting","quantified","validated","mechanisms","exemplary","dimensional","clustering","partitioned","exploratory","associations","association","comparing","elucidating","provenance","membership","effective","technique","uninformative","probabilistic","constructed","algorithms","unsupervised","classification","partitions","variables","developing","heterogeneity","advantages","probabilities","limitations","statisticians","difficulty","attention","bandwidth","generating","applications","conditional","prediction","fundamental","presumably","applicable","criterion","techniques","bivariate","relatively","experiments","estimation","intractable","intervals","generalizes","previously","estimator","likelihood","nonparametric","computational","selection","estimators","important","multivariate","community","regression","necessary","guaranteed","hypotheses","condition","subspaces","introduce","separable","learnability","measurable","universally","compactness","compression","additionally","increasing","functions","aforementioned","asymptote","algorithm","structure","separately","activation","generalization","sufficient","empirically","rectified","conditions","separability","intuitions","concretely","minimizing","optimization","stochastic","constraints","feasibility","convergence","structural","violation","literature","alternating","necessarily","multipliers","augmented","assumptions","nonsmooth","establish","objective","direction","demonstrate","semantically","leverages","controllable","continuous","generative","correspond","supervised","categorical","adversarial","supervision","categories","maximizing","furthermore","disentangle","synthesis","contribute","representations","synthetic","reasoning","increases","information","architecture","theoretic","introducing","available","maintains","meaningful","consuming","traditional","recognize","different","physicians","examination","investigate","automatic","subjective","detection","involving","annotated","evaluating","comprehensively","consisting","intensive","microscopic","corresponding","particles","similarity","precision","euclidean","producing","overlapped","closeness","observations","overlapping","divergence","correctness","components","asymptotic","numerical","nonconvex","hypothesis","statistical","stationary","efficient","nonlinear","specifically","nonconvexity","parameter","confidence","uncertainty","construct","converges","classical","regularized","inference","nonlinearity","implementation","differentiable","gradients","predictions","indistinguishable","identifying","convolutional","debugging","understanding","detecting","influence","statistics","approximations","responsible","programming","management","scheduling","definition","determining","specifications","programing","prominent","constrained","constraint","consistency","approaches","pathology","improvement","favorably","pathologies","independently","performing","computing","predictive","benchmark","decoupled","performance","collected","exploration","expensive","encounter","heuristic","parameterized","maintained","parameters","maximally","threshold","relevance","processes","distribution","computationally","scientific","optimizing","experiment","predicted","potential","informative","autonomous ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	statisticians
# 	measurable
# 	trilinear
# 	nutrition
# 	activating
# 	advection
# 	divisible
# 	encrypted
# 	heartbeats
# 	reparametrizations
# 	sketching
# 	influencing
# 	spectroradiometer
# 	reflectivity
# 	binarycategorical
# 	physician
# 	hypersphere
# 	pharmacokinetic
# 	multipartite
# 	differentiates
# Some words which never appear in Statistics papers:
# 	transcriptions
# 	specifications
# 	programing
# 	counterintuitive
# 	unpredictable
# 	terrorism
# 	photometric
# 	illumination
# 	lambertian
# 	insertion
# 	evidential
# 	philosophical
# 	justifications
# 	sociological
# 	tracklets
# 	rotationally
# 	depiction
# 	orientations
# 	steerable
# 	presently

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.067955207853966e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7725
